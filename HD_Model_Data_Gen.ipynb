# %% [markdown]
# # Hard Drive Model Data Generator
# * pulls out many features over all times for all drives of a given MODEL
# * prepares data for time series machine learning
# * writes a .csv (into OUTPUT_DIR) for each unqiue 'serial_number' of a given MODEL
# * the output data features include all columns that contain the string FEATURE_COL
# * note: generates many files!

# %%
import os
import pandas as pd
import numpy as np
from time import gmtime, strftime, time
import logging
import sys

# %%
MODEL = 'ST4000DM000'
TEST = False
DATA_DIR = "data/"
DATA_FOLDERS = ["2014","2015","data_Q1_2016","data_Q2_2016","data_Q3_2016","data_Q4_2016"]
NAN_FRAC = .25 
FEATURE_COL = "raw"
THE_TIME = strftime("%Y-%m-%d-%H-%S", gmtime())
OUTPUT_DIR = MODEL + "_data"

# %% [markdown]
# Sets up a custom logger that will work with ipython, repeated calls to this piece of code without restarting the IPython kernel will result in creating and attaching yet another handler to the logger on every run and the number of messages being logged to the file with each log call will grow

# %%
def start_logger():
    if os.path.isdir(OUTPUT_DIR):
        os.system("rm " + OUTPUT_DIR + "/*")
        os.system("rmdir " + OUTPUT_DIR)
    os.system("mkdir " + OUTPUT_DIR)
    root_logger = logging.getLogger()
    root_logger.setLevel(logging.DEBUG)
    logger = logging.getLogger(__name__)
    logfile = OUTPUT_DIR + '/' + THE_TIME + ".log"
    handler = logging.FileHandler(logfile, 'w')
    handler.setLevel(logging.INFO)
    logger.addHandler(handler)
    logger.info("MODEL\t=\t" + MODEL)
    logger.info("TEST\t=\t" + str(TEST))
    logger.info("DATA_DIR\t=\t" + DATA_DIR)
    logger.info("OUTPUT_DIR\t=\t" + OUTPUT_DIR)
    logger.info("THE_TIME\t=\t" + THE_TIME)
    logger.info("FEATURE_COL\t=\t" + FEATURE_COL)
    logger.info("NAN_FRAC\t=\t" + str(NAN_FRAC))
    return logger

# %% [markdown]
# ### select specific MODEL and drop columns that do not contain FEATURE_COL, are date or are serial

# %%
def sift_data(data):
    sifted_data = pd.DataFrame.copy(data[data['model'] == MODEL])
    for ikey in sifted_data.keys():
        if FEATURE_COL not in ikey and ikey != 'serial_number' and ikey != 'failure' and ikey != 'date':
                del sifted_data[ikey]
    return sifted_data

# %% [markdown]
# ### drop columns that are all NaN or have more than NAN_FRACTION

# %%
 def clean_data(data):
    hd_clean = data.dropna(axis=1, how='all')
    for ikey in hd_clean.keys():
        column_nan_count = hd_clean[ikey].isnull().sum()
        logger.info("%d NaN fraction of:\t %s" % (column_nan_count/len(hd_clean), ikey))
        if column_nan_count / len(hd_clean) >= NAN_FRAC:
            logger.info("Dropping column: %s" % ikey)
            hd_clean = hd_clean.drop(ikey, 1)#, inplace=True)

    for ikey in hd_clean.keys():
        column_unique_count = len(hd_clean[ikey].unique())
        logging.info("%d unique value count of:\t %s" % (column_unique_count, ikey))
        #if column_unique_count == 1 and ikey != 'failure':
        #        logging.info("Dropping column: %s" % ikey)
        #        hd_clean = hd_clean.drop(ikey, 1)#, inplace=True)

    hd_clean = hd_clean.fillna(666)

    for ikey in hd_clean.keys():
        column_nan_count = hd_clean[ikey].isnull().sum()
        if column_nan_count > 0:
            logger.warning("Warning! There shouldn't be any NaNs but there are in %s" % ikey)
    return hd_clean

# %% [markdown]
# ### main loop

# %%
logger = start_logger()
start_time = time()

for data_dir in DATA_FOLDERS:
    data_dir = DATA_DIR + data_dir + "/"
    hd = pd.DataFrame()
    #logger.info("* * * \nLoading: %s" % data_dir)
    logger.info(" ### ### ### ### ### ### ### ### ### ### #### ### ###")
    logger.info("Working with: %s" % data_dir)
    logger.info("Elapsed time: %s seconds" % np.round(time() - start_time,1))
    #print("Working with: %s" % model)
    
    
    
    for data_file in os.listdir(data_dir):
        if data_file.split('.')[1] == 'csv':
            if TEST:
                temp = pd.read_csv(data_dir+data_file, header=0, nrows=200)
                temp = sift_data(temp)
            else:
                temp = pd.read_csv(data_dir + data_file, header=0)
                temp = sift_data(temp)
            hd = hd.append(temp)

    logger.info("Working on: %s" % data_dir)
    logger.info("Shape of this data: %s" % str(np.shape(hd)))
    logger.info("There are %d unique drives. " % len(hd['serial_number'].unique()))    
    logger.info("There are %d failures." % hd['failure'].sum())

    clean = clean_data(hd)
    
    logger.info("There are %d unique drives after cleaning. " % len(clean['serial_number'].unique()))
    logger.info("There are %d failures after cleaning." % clean['failure'].sum())
    
    serial_grouped = clean.groupby(['serial_number'])
    serial_grouped = list(serial_grouped)

    logger.info("Writing serial csv files from %s" % data_dir)

    for i in range((len(serial_grouped))):
        fname = OUTPUT_DIR + "/" + serial_grouped[i][0] + '.csv'
        individual_serial_data = serial_grouped[i][1]
        if os.path.exists(fname):
            f = open(fname, 'a')
        else:
            f = open(fname, 'w')
        f.write("#" + str(np.shape(individual_serial_data)[0]) + ",")
        f.write(str(np.shape(individual_serial_data)[1]) + ",")
        f.write(data_dir + "\n#")
        f.close()
        del individual_serial_data['serial_number']
        individual_serial_data = individual_serial_data.sort_values(by=['smart_9_raw'])
        individual_serial_data.to_csv(path_or_buf=fname, sep=',', header=True, index=False, mode='a',
                                      encoding='utf-8')
        #if TEST:
        #    if i >= 10:
        #        break


#log_file.close()
# Out:
# INFO:root:364 unique value count of:	 date
# INFO:root:12920 unique value count of:	 serial_number
# INFO:root:2 unique value count of:	 failure
# INFO:root:3186706 unique value count of:	 smart_1_raw
# INFO:root:2 unique value count of:	 smart_3_raw
# INFO:root:123 unique value count of:	 smart_4_raw
# INFO:root:557 unique value count of:	 smart_5_raw
# INFO:root:3111730 unique value count of:	 smart_7_raw
# INFO:root:13646 unique value count of:	 smart_9_raw
# INFO:root:2 unique value count of:	 smart_10_raw
# INFO:root:103 unique value count of:	 smart_12_raw
# INFO:root:3 unique value count of:	 smart_15_raw
# INFO:root:429 unique value count of:	 smart_183_raw
# INFO:root:7 unique value count of:	 smart_184_raw
# INFO:root:463 unique value count of:	 smart_187_raw
# INFO:root:1731 unique value count of:	 smart_188_raw
# INFO:root:671 unique value count of:	 smart_189_raw
# INFO:root:29 unique value count of:	 smart_190_raw
# INFO:root:2 unique value count of:	 smart_191_raw
# INFO:root:73 unique value count of:	 smart_192_raw
# INFO:root:91616 unique value count of:	 smart_193_raw
# INFO:root:29 unique value count of:	 smart_194_raw
# INFO:root:399 unique value count of:	 smart_197_raw
# INFO:root:341 unique value count of:	 smart_198_raw
# INFO:root:1359 unique value count of:	 smart_199_raw
# INFO:root:2825161 unique value count of:	 smart_240_raw
# INFO:root:3115312 unique value count of:	 smart_241_raw
# INFO:root:3116080 unique value count of:	 smart_242_raw
# INFO:root:3 unique value count of:	 smart_255_raw
# INFO:__main__:There are 12920 unique drives after cleaning.
# INFO:__main__:There are 238 failures after cleaning.
# INFO:__main__:Writing serial csv files from data/2014/
# INFO:__main__: ### ### ### ### ### ### ### ### ### ### #### ### ###
# INFO:__main__:Working with: data/2015/
# INFO:__main__:Elapsed time: 1201.5 seconds
# INFO:__main__:Working on: data/2015/
# INFO:__main__:Shape of this data: (6782765, 48)
# INFO:__main__:There are 29670 unique drives.
# INFO:__main__:There are 586 failures.
# INFO:__main__:0 NaN fraction of:	 date
# INFO:__main__:0 NaN fraction of:	 serial_number
# INFO:__main__:0 NaN fraction of:	 failure
# INFO:__main__:0 NaN fraction of:	 smart_1_raw
# INFO:__main__:0 NaN fraction of:	 smart_3_raw
# INFO:__main__:0 NaN fraction of:	 smart_4_raw
# INFO:__main__:0 NaN fraction of:	 smart_5_raw
# INFO:__main__:0 NaN fraction of:	 smart_7_raw
# INFO:__main__:0 NaN fraction of:	 smart_9_raw
# INFO:__main__:0 NaN fraction of:	 smart_10_raw
# INFO:__main__:0 NaN fraction of:	 smart_12_raw
# INFO:__main__:0 NaN fraction of:	 smart_183_raw
# INFO:__main__:0 NaN fraction of:	 smart_184_raw
# INFO:__main__:0 NaN fraction of:	 smart_187_raw
# INFO:__main__:0 NaN fraction of:	 smart_188_raw
# INFO:__main__:0 NaN fraction of:	 smart_189_raw
# INFO:__main__:0 NaN fraction of:	 smart_190_raw
# INFO:__main__:0 NaN fraction of:	 smart_191_raw
# INFO:__main__:0 NaN fraction of:	 smart_192_raw
# INFO:__main__:0 NaN fraction of:	 smart_193_raw
# INFO:__main__:0 NaN fraction of:	 smart_194_raw
# INFO:__main__:0 NaN fraction of:	 smart_197_raw
# INFO:__main__:0 NaN fraction of:	 smart_198_raw
# INFO:__main__:0 NaN fraction of:	 smart_199_raw
# INFO:__main__:0 NaN fraction of:	 smart_240_raw
# INFO:__main__:0 NaN fraction of:	 smart_241_raw
# INFO:__main__:0 NaN fraction of:	 smart_242_raw
# INFO:root:364 unique value count of:	 date
# INFO:root:29670 unique value count of:	 serial_number
# INFO:root:2 unique value count of:	 failure
# INFO:root:5994654 unique value count of:	 smart_1_raw
# INFO:root:2 unique value count of:	 smart_3_raw
# INFO:root:150 unique value count of:	 smart_4_raw
# INFO:root:787 unique value count of:	 smart_5_raw
# INFO:root:6743184 unique value count of:	 smart_7_raw
# INFO:root:22477 unique value count of:	 smart_9_raw
# INFO:root:2 unique value count of:	 smart_10_raw
# INFO:root:104 unique value count of:	 smart_12_raw
# INFO:root:740 unique value count of:	 smart_183_raw
# INFO:root:7 unique value count of:	 smart_184_raw
# INFO:root:139 unique value count of:	 smart_187_raw
# INFO:root:954 unique value count of:	 smart_188_raw
# INFO:root:1157 unique value count of:	 smart_189_raw
# INFO:root:30 unique value count of:	 smart_190_raw
# INFO:root:2 unique value count of:	 smart_191_raw
# INFO:root:96 unique value count of:	 smart_192_raw
# INFO:root:78868 unique value count of:	 smart_193_raw
# INFO:root:30 unique value count of:	 smart_194_raw
# INFO:root:133 unique value count of:	 smart_197_raw
# INFO:root:133 unique value count of:	 smart_198_raw
# INFO:root:852 unique value count of:	 smart_199_raw
# INFO:root:2830760 unique value count of:	 smart_240_raw
# INFO:root:6774458 unique value count of:	 smart_241_raw
# INFO:root:6777638 unique value count of:	 smart_242_raw
# INFO:__main__:There are 29670 unique drives after cleaning.
# INFO:__main__:There are 586 failures after cleaning.
# INFO:__main__:Writing serial csv files from data/2015/
# INFO:__main__: ### ### ### ### ### ### ### ### ### ### #### ### ###
# INFO:__main__:Working with: data/data_Q1_2016/
# INFO:__main__:Elapsed time: 3336.1 seconds
# INFO:__main__:Working on: data/data_Q1_2016/
# INFO:__main__:Shape of this data: (2883058, 48)
# INFO:__main__:There are 34988 unique drives.
# INFO:__main__:There are 200 failures.
# INFO:__main__:0 NaN fraction of:	 date
# INFO:__main__:0 NaN fraction of:	 serial_number
# INFO:__main__:0 NaN fraction of:	 failure
# INFO:__main__:0 NaN fraction of:	 smart_1_raw
# INFO:__main__:0 NaN fraction of:	 smart_3_raw
# INFO:__main__:0 NaN fraction of:	 smart_4_raw
# INFO:__main__:0 NaN fraction of:	 smart_5_raw
# INFO:__main__:0 NaN fraction of:	 smart_7_raw
# INFO:__main__:0 NaN fraction of:	 smart_9_raw
# INFO:__main__:0 NaN fraction of:	 smart_10_raw
# INFO:__main__:0 NaN fraction of:	 smart_12_raw
# INFO:__main__:0 NaN fraction of:	 smart_183_raw
# INFO:__main__:0 NaN fraction of:	 smart_184_raw
# INFO:__main__:0 NaN fraction of:	 smart_187_raw
# INFO:__main__:0 NaN fraction of:	 smart_188_raw
# INFO:__main__:0 NaN fraction of:	 smart_189_raw
# INFO:__main__:0 NaN fraction of:	 smart_190_raw
# INFO:__main__:0 NaN fraction of:	 smart_191_raw
# INFO:__main__:0 NaN fraction of:	 smart_192_raw
# INFO:__main__:0 NaN fraction of:	 smart_193_raw
# INFO:__main__:0 NaN fraction of:	 smart_194_raw
# INFO:__main__:0 NaN fraction of:	 smart_197_raw
# INFO:__main__:0 NaN fraction of:	 smart_198_raw
# INFO:__main__:0 NaN fraction of:	 smart_199_raw
# INFO:__main__:0 NaN fraction of:	 smart_240_raw
# INFO:__main__:0 NaN fraction of:	 smart_241_raw
# INFO:__main__:0 NaN fraction of:	 smart_242_raw
# INFO:root:91 unique value count of:	 date
# INFO:root:34988 unique value count of:	 serial_number
# INFO:root:2 unique value count of:	 failure
# INFO:root:2713606 unique value count of:	 smart_1_raw
# INFO:root:2 unique value count of:	 smart_3_raw
# INFO:root:106 unique value count of:	 smart_4_raw
# INFO:root:253 unique value count of:	 smart_5_raw
# INFO:root:2873999 unique value count of:	 smart_7_raw
# INFO:root:22721 unique value count of:	 smart_9_raw
# INFO:root:2 unique value count of:	 smart_10_raw
# INFO:root:78 unique value count of:	 smart_12_raw
# INFO:root:91 unique value count of:	 smart_183_raw
# INFO:root:5 unique value count of:	 smart_184_raw
# INFO:root:33 unique value count of:	 smart_187_raw
# INFO:root:119 unique value count of:	 smart_188_raw
# INFO:root:428 unique value count of:	 smart_189_raw
# INFO:root:31 unique value count of:	 smart_190_raw
# INFO:root:2 unique value count of:	 smart_191_raw
# INFO:root:85 unique value count of:	 smart_192_raw
# INFO:root:55288 unique value count of:	 smart_193_raw
# INFO:root:31 unique value count of:	 smart_194_raw
# INFO:root:44 unique value count of:	 smart_197_raw
# INFO:root:44 unique value count of:	 smart_198_raw
# INFO:root:174 unique value count of:	 smart_199_raw
# INFO:root:248455 unique value count of:	 smart_240_raw
# INFO:root:2878787 unique value count of:	 smart_241_raw
# INFO:root:2880589 unique value count of:	 smart_242_raw
# INFO:__main__:There are 34988 unique drives after cleaning.
# INFO:__main__:There are 200 failures after cleaning.
# INFO:__main__:Writing serial csv files from data/data_Q1_2016/
# INFO:__main__: ### ### ### ### ### ### ### ### ### ### #### ### ###
# INFO:__main__:Working with: data/data_Q2_2016/
# INFO:__main__:Elapsed time: 3779.6 seconds
# INFO:__main__:Working on: data/data_Q2_2016/
# INFO:__main__:Shape of this data: (3126610, 48)
# INFO:__main__:There are 34965 unique drives.
# INFO:__main__:There are 228 failures.
# INFO:__main__:0 NaN fraction of:	 date
# INFO:__main__:0 NaN fraction of:	 serial_number
# INFO:__main__:0 NaN fraction of:	 failure
# INFO:__main__:0 NaN fraction of:	 smart_1_raw
# INFO:__main__:0 NaN fraction of:	 smart_3_raw
# INFO:__main__:0 NaN fraction of:	 smart_4_raw
# INFO:__main__:0 NaN fraction of:	 smart_5_raw
# INFO:__main__:0 NaN fraction of:	 smart_7_raw
# INFO:__main__:0 NaN fraction of:	 smart_9_raw
# INFO:__main__:0 NaN fraction of:	 smart_10_raw
# INFO:__main__:0 NaN fraction of:	 smart_12_raw
# INFO:__main__:0 NaN fraction of:	 smart_183_raw
# INFO:__main__:0 NaN fraction of:	 smart_184_raw
# INFO:__main__:0 NaN fraction of:	 smart_187_raw
# INFO:__main__:0 NaN fraction of:	 smart_188_raw
# INFO:__main__:0 NaN fraction of:	 smart_189_raw
# INFO:__main__:0 NaN fraction of:	 smart_190_raw
# INFO:__main__:0 NaN fraction of:	 smart_191_raw
# INFO:__main__:0 NaN fraction of:	 smart_192_raw
# INFO:__main__:0 NaN fraction of:	 smart_193_raw
# INFO:__main__:0 NaN fraction of:	 smart_194_raw
# INFO:__main__:0 NaN fraction of:	 smart_197_raw
# INFO:__main__:0 NaN fraction of:	 smart_198_raw
# INFO:__main__:0 NaN fraction of:	 smart_199_raw
# INFO:__main__:0 NaN fraction of:	 smart_240_raw
# INFO:__main__:0 NaN fraction of:	 smart_241_raw
# INFO:__main__:0 NaN fraction of:	 smart_242_raw
# INFO:root:91 unique value count of:	 date
# INFO:root:34965 unique value count of:	 serial_number
# INFO:root:2 unique value count of:	 failure
# INFO:root:2963792 unique value count of:	 smart_1_raw
# INFO:root:1 unique value count of:	 smart_3_raw
# INFO:root:101 unique value count of:	 smart_4_raw
# INFO:root:259 unique value count of:	 smart_5_raw
# INFO:root:3119355 unique value count of:	 smart_7_raw
# INFO:root:24641 unique value count of:	 smart_9_raw
# INFO:root:1 unique value count of:	 smart_10_raw
# INFO:root:79 unique value count of:	 smart_12_raw
# INFO:root:90 unique value count of:	 smart_183_raw
# INFO:root:4 unique value count of:	 smart_184_raw
# INFO:root:36 unique value count of:	 smart_187_raw
# INFO:root:55 unique value count of:	 smart_188_raw
# INFO:root:415 unique value count of:	 smart_189_raw
# INFO:root:32 unique value count of:	 smart_190_raw
# INFO:root:1 unique value count of:	 smart_191_raw
# INFO:root:63 unique value count of:	 smart_192_raw
# INFO:root:66072 unique value count of:	 smart_193_raw
# INFO:root:32 unique value count of:	 smart_194_raw
# INFO:root:36 unique value count of:	 smart_197_raw
# INFO:root:36 unique value count of:	 smart_198_raw
# INFO:root:145 unique value count of:	 smart_199_raw
# INFO:root:59373 unique value count of:	 smart_240_raw
# INFO:root:3125749 unique value count of:	 smart_241_raw
# INFO:root:3126349 unique value count of:	 smart_242_raw
# INFO:__main__:There are 34965 unique drives after cleaning.
# INFO:__main__:There are 228 failures after cleaning.
# INFO:__main__:Writing serial csv files from data/data_Q2_2016/
# INFO:__main__: ### ### ### ### ### ### ### ### ### ### #### ### ###
# INFO:__main__:Working with: data/data_Q3_2016/
# INFO:__main__:Elapsed time: 4263.6 seconds
# INFO:__main__:Working on: data/data_Q3_2016/
# INFO:__main__:Shape of this data: (3187409, 48)
# INFO:__main__:There are 35022 unique drives.
# INFO:__main__:There are 278 failures.
# INFO:__main__:0 NaN fraction of:	 date
# INFO:__main__:0 NaN fraction of:	 serial_number
# INFO:__main__:0 NaN fraction of:	 failure
# INFO:__main__:0 NaN fraction of:	 smart_1_raw
# INFO:__main__:0 NaN fraction of:	 smart_3_raw
# INFO:__main__:0 NaN fraction of:	 smart_4_raw
# INFO:__main__:0 NaN fraction of:	 smart_5_raw
# INFO:__main__:0 NaN fraction of:	 smart_7_raw
# INFO:__main__:0 NaN fraction of:	 smart_9_raw
# INFO:__main__:0 NaN fraction of:	 smart_10_raw
# INFO:__main__:0 NaN fraction of:	 smart_12_raw
# INFO:__main__:0 NaN fraction of:	 smart_183_raw
# INFO:__main__:0 NaN fraction of:	 smart_184_raw
# INFO:__main__:0 NaN fraction of:	 smart_187_raw
# INFO:__main__:0 NaN fraction of:	 smart_188_raw
# INFO:__main__:0 NaN fraction of:	 smart_189_raw
# INFO:__main__:0 NaN fraction of:	 smart_190_raw
# INFO:__main__:0 NaN fraction of:	 smart_191_raw
# INFO:__main__:0 NaN fraction of:	 smart_192_raw
# INFO:__main__:0 NaN fraction of:	 smart_193_raw
# INFO:__main__:0 NaN fraction of:	 smart_194_raw
# INFO:__main__:0 NaN fraction of:	 smart_197_raw
# INFO:__main__:0 NaN fraction of:	 smart_198_raw
# INFO:__main__:0 NaN fraction of:	 smart_199_raw
# INFO:__main__:0 NaN fraction of:	 smart_240_raw
# INFO:__main__:0 NaN fraction of:	 smart_241_raw
# INFO:__main__:0 NaN fraction of:	 smart_242_raw
# INFO:root:92 unique value count of:	 date
# INFO:root:35022 unique value count of:	 serial_number
# INFO:root:2 unique value count of:	 failure
# INFO:root:3026503 unique value count of:	 smart_1_raw
# INFO:root:1 unique value count of:	 smart_3_raw
# INFO:root:130 unique value count of:	 smart_4_raw
# INFO:root:287 unique value count of:	 smart_5_raw
# INFO:root:3180025 unique value count of:	 smart_7_raw
# INFO:root:26720 unique value count of:	 smart_9_raw
# INFO:root:1 unique value count of:	 smart_10_raw
# INFO:root:88 unique value count of:	 smart_12_raw
# INFO:root:92 unique value count of:	 smart_183_raw
# INFO:root:5 unique value count of:	 smart_184_raw
# INFO:root:41 unique value count of:	 smart_187_raw
# INFO:root:68 unique value count of:	 smart_188_raw
# INFO:root:432 unique value count of:	 smart_189_raw
# INFO:root:35 unique value count of:	 smart_190_raw
# INFO:root:1 unique value count of:	 smart_191_raw
# INFO:root:88 unique value count of:	 smart_192_raw
# INFO:root:75549 unique value count of:	 smart_193_raw
# INFO:root:35 unique value count of:	 smart_194_raw
# INFO:root:35 unique value count of:	 smart_197_raw
# INFO:root:35 unique value count of:	 smart_198_raw
# INFO:root:138 unique value count of:	 smart_199_raw
# INFO:root:29075 unique value count of:	 smart_240_raw
# INFO:root:3186491 unique value count of:	 smart_241_raw
# INFO:root:3187283 unique value count of:	 smart_242_raw
# INFO:__main__:There are 35022 unique drives after cleaning.
# INFO:__main__:There are 278 failures after cleaning.
# INFO:__main__:Writing serial csv files from data/data_Q3_2016/
# INFO:__main__: ### ### ### ### ### ### ### ### ### ### #### ### ###
# INFO:__main__:Working with: data/data_Q4_2016/
# INFO:__main__:Elapsed time: 4788.2 seconds
# INFO:__main__:Working on: data/data_Q4_2016/
# INFO:__main__:Shape of this data: (3196552, 48)
# INFO:__main__:There are 34970 unique drives.
# INFO:__main__:There are 234 failures.
# INFO:__main__:0 NaN fraction of:	 date
# INFO:__main__:0 NaN fraction of:	 serial_number
# INFO:__main__:0 NaN fraction of:	 failure
# INFO:__main__:0 NaN fraction of:	 smart_1_raw
# INFO:__main__:0 NaN fraction of:	 smart_3_raw
# INFO:__main__:0 NaN fraction of:	 smart_4_raw
# INFO:__main__:0 NaN fraction of:	 smart_5_raw
# INFO:__main__:0 NaN fraction of:	 smart_7_raw
# INFO:__main__:0 NaN fraction of:	 smart_9_raw
# INFO:__main__:0 NaN fraction of:	 smart_10_raw
# INFO:__main__:0 NaN fraction of:	 smart_12_raw
# INFO:__main__:0 NaN fraction of:	 smart_183_raw
# INFO:__main__:0 NaN fraction of:	 smart_184_raw
# INFO:__main__:0 NaN fraction of:	 smart_187_raw
# INFO:__main__:0 NaN fraction of:	 smart_188_raw
# INFO:__main__:0 NaN fraction of:	 smart_189_raw
# INFO:__main__:0 NaN fraction of:	 smart_190_raw
# INFO:__main__:0 NaN fraction of:	 smart_191_raw
# INFO:__main__:0 NaN fraction of:	 smart_192_raw
# INFO:__main__:0 NaN fraction of:	 smart_193_raw
# INFO:__main__:0 NaN fraction of:	 smart_194_raw
# INFO:__main__:0 NaN fraction of:	 smart_197_raw
# INFO:__main__:0 NaN fraction of:	 smart_198_raw
# INFO:__main__:0 NaN fraction of:	 smart_199_raw
# INFO:__main__:0 NaN fraction of:	 smart_240_raw
# INFO:__main__:0 NaN fraction of:	 smart_241_raw
# INFO:__main__:0 NaN fraction of:	 smart_242_raw
# INFO:root:92 unique value count of:	 date
# INFO:root:34970 unique value count of:	 serial_number
# INFO:root:2 unique value count of:	 failure
# INFO:root:3035074 unique value count of:	 smart_1_raw
# INFO:root:1 unique value count of:	 smart_3_raw
# INFO:root:137 unique value count of:	 smart_4_raw
# INFO:root:315 unique value count of:	 smart_5_raw
# INFO:root:3189177 unique value count of:	 smart_7_raw
# INFO:root:29175 unique value count of:	 smart_9_raw
# INFO:root:1 unique value count of:	 smart_10_raw
# INFO:root:90 unique value count of:	 smart_12_raw
# INFO:root:97 unique value count of:	 smart_183_raw
# INFO:root:6 unique value count of:	 smart_184_raw
# INFO:root:34 unique value count of:	 smart_187_raw
# INFO:root:49 unique value count of:	 smart_188_raw
# INFO:root:418 unique value count of:	 smart_189_raw
# INFO:root:34 unique value count of:	 smart_190_raw
# INFO:root:1 unique value count of:	 smart_191_raw
# INFO:root:79 unique value count of:	 smart_192_raw
# INFO:root:113414 unique value count of:	 smart_193_raw
# INFO:root:34 unique value count of:	 smart_194_raw
# INFO:root:35 unique value count of:	 smart_197_raw
# INFO:root:35 unique value count of:	 smart_198_raw
# INFO:root:123 unique value count of:	 smart_199_raw
# INFO:root:31344 unique value count of:	 smart_240_raw
# INFO:root:3195561 unique value count of:	 smart_241_raw
# INFO:root:3196435 unique value count of:	 smart_242_raw
# INFO:__main__:There are 34970 unique drives after cleaning.
# INFO:__main__:There are 234 failures after cleaning.
# INFO:__main__:Writing serial csv files from data/data_Q4_2016/
